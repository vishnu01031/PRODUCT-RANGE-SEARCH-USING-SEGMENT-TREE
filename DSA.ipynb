# %%
import csv
import os

# ===================== Segment Tree (merge-sort tree) =====================
class SegmentTree:
    def __init__(self, prices):
        """
        prices : list of (price:int, index:int)
        The root is stored at idx = 0; children: 2*idx+1, 2*idx+2
        Each node stores a sorted list of (price, index) for that segment.
        """
        self.n = len(prices)
        if self.n == 0:
            self.tree = []
        else:
            self.tree = [[] for _ in range(4 * self.n)]
            self.build(prices, 0, self.n - 1, 0)

    def merge_sorted_lists(self, left, right):
        """Merge two sorted lists of (price, index) into one sorted list."""
        res = []
        i = 0
        j = 0
        while i < len(left) and j < len(right):
            if left[i][0] <= right[j][0]:
                res.append(left[i])
                i += 1
            else:
                res.append(right[j])
                j += 1
        # append tails
        while i < len(left):
            res.append(left[i])
            i += 1
        while j < len(right):
            res.append(right[j])
            j += 1
        return res

    def build(self, prices, l, r, idx):
        """Build node idx for segment [l, r] from prices list."""
        if l == r:
            # leaf: single element list
            self.tree[idx] = [(prices[l][0], prices[l][1])]
            return
        mid = (l + r) // 2
        self.build(prices, l, mid, 2 * idx + 1)
        self.build(prices, mid + 1, r, 2 * idx + 2)
        left_list = self.tree[2 * idx + 1]
        right_list = self.tree[2 * idx + 2]
        self.tree[idx] = self.merge_sorted_lists(left_list, right_list)

    def update(self, pos, old_price, new_price, l, r, idx):
        """
        Update the element at array index `pos`: old_price -> new_price.
        We update the current node's list (remove old pair, insert new pair in sorted order),
        then recurse to the child containing pos.
        """
        # remove any pair that exactly matches (old_price, pos)
        cur = []
        for (p, i) in self.tree[idx]:
            if not (p == old_price and i == pos):
                cur.append((p, i))

        # insert (new_price, pos) in sorted order without using sorted()
        inserted = False
        newlist = []
        for (p, i) in cur:
            if not inserted and new_price <= p:
                newlist.append((new_price, pos))
                inserted = True
            newlist.append((p, i))
        if not inserted:
            newlist.append((new_price, pos))
        self.tree[idx] = newlist

        # if leaf, stop
        if l == r:
            return

        mid = (l + r) // 2
        if pos <= mid:
            self.update(pos, old_price, new_price, l, mid, 2 * idx + 1)
        else:
            self.update(pos, old_price, new_price, mid + 1, r, 2 * idx + 2)

    def range_query(self, ql, qr, low, high, l, r, idx):
        """
        Return list of (price, index) that are within index-range [ql, qr]
        and have price in [low, high].
        """
        if ql > r or qr < l:
            return []
        if ql <= l and r <= qr:
            # node fully inside index-range -> filter by price
            out = []
            for (p, i) in self.tree[idx]:
                if low <= p <= high:
                    out.append((p, i))
            return out
        mid = (l + r) // 2
        left_res = self.range_query(ql, qr, low, high, l, mid, 2 * idx + 1)
        right_res = self.range_query(ql, qr, low, high, mid + 1, r, 2 * idx + 2)
        return left_res + right_res


# ===================== Product System =====================
class ProductSystem:
    def __init__(self, filename):
        self.filename = filename
        self.products = []   # list of dicts: {"Product_ID", "Price", "Category", "Date"}
        self.seg_tree = None
        # ensure file exists with header
        if not os.path.exists(self.filename):
            with open(self.filename, "w", newline="") as f:
                writer = csv.writer(f)
                writer.writerow(["Product_ID", "Price", "Category", "Date"])
        # load and build
        self.load_file()
        self.build_tree()

    # ---------------- File Handling ---------------- #
    def load_file(self):
        self.products = []
        try:
            with open(self.filename, "r", newline="") as f:
                reader = csv.DictReader(f)
                # manual loop, no enumerate
                for row in reader:
                    # skip empty rows
                    if not row:
                        continue
                    pid = row.get("Product_ID", "").strip()
                    price_str = (row.get("Price", "") or "").strip()
                    category = row.get("Category", "").strip()
                    date = row.get("Date", "").strip()

                    # safe price parse: empty or non-digit -> 0
                    if price_str == "":
                        price = 0
                    else:
                        # handle possible spaces or non-digit characters gracefully
                        try:
                            price = int(price_str)
                        except ValueError:
                            # fallback: extract digits if possible, else 0
                            digits = "".join(ch for ch in price_str if ch.isdigit())
                            price = int(digits) if digits else 0

                    # only store if Product_ID present (skip malformed rows)
                    if pid != "":
                        self.products.append({
                            "Product_ID": pid,
                            "Price": price,
                            "Category": category,
                            "Date": date
                        })
        except FileNotFoundError:
            self.products = []

    def save_file(self):
        """Write back to the same CSV safely (write temp then replace)."""
        temp_file = self.filename + ".tmp"
        try:
            with open(temp_file, "w", newline="") as f:
                fieldnames = ["Product_ID", "Price", "Category", "Date"]
                writer = csv.DictWriter(f, fieldnames)
                writer.writeheader()
                # manual loop for writerows to ensure consistent ordering
                for p in self.products:
                    writer.writerow({
                        "Product_ID": p["Product_ID"],
                        "Price": p["Price"],
                        "Category": p["Category"],
                        "Date": p["Date"]
                    })
            # atomic replace
            os.replace(temp_file, self.filename)
        except PermissionError as e:
            # if permission error (file open elsewhere), inform user and remove temp file if exists
            if os.path.exists(temp_file):
                try:
                    os.remove(temp_file)
                except Exception:
                    pass
            raise PermissionError(f"Cannot write to {self.filename}. Close any programs (Excel) using it.") from e

    # ---------------- Tree Handling ---------------- #
    def build_tree(self):
        """Create the prices list (price, index) without using enumerate."""
        n = 0
        prices = []
        # manual index counter
        idx = 0
        while idx < len(self.products):
            p = self.products[idx]
            prices.append((p["Price"], idx))
            idx += 1
            n += 1
        if n == 0:
            self.seg_tree = None
        else:
            self.seg_tree = SegmentTree(prices)

    # ---------------- Product Operations ---------------- #
    def insert(self, product_id, price, category, date):
        """Insert product; if product_id exists, update existing product instead."""
        # check for existing Product_ID (manual loop)
        i = 0
        while i < len(self.products):
            if self.products[i]["Product_ID"] == product_id:
                # exists -> update
                self.products[i]["Price"] = int(price)
                self.products[i]["Category"] = category
                self.products[i]["Date"] = date
                self.save_file()
                self.build_tree()
                return
            i += 1

        # not found -> append
        new_product = {
            "Product_ID": product_id,
            "Price": int(price),
            "Category": category,
            "Date": date
        }
        self.products.append(new_product)
        self.save_file()
        self.build_tree()
        print(f"Inserted product {product_id} successfully.")

    def update_price(self, product_id, new_price):
        """Update price by Product_ID and update segment tree."""
        pos = None
        i = 0
        while i < len(self.products):
            if self.products[i]["Product_ID"] == product_id:
                pos = i
                break
            i += 1

        if pos is None:
            print(f"Product {product_id} not found.")
            return

        old_price = self.products[pos]["Price"]
        new_price_int = int(new_price)
        self.products[pos]["Price"] = new_price_int

        if self.seg_tree:
            # update merge-sort tree in-place
            self.seg_tree.update(pos, old_price, new_price_int,
                                 0, len(self.products) - 1, 0)
        else:
            # no tree -> rebuild
            self.build_tree()

        self.save_file()
        print(f"Updated price of {product_id} from {old_price} to {new_price_int}.")

    def filter_by_price(self, low, high):
        """Return list of product dicts whose Price in [low, high]."""
        if not self.seg_tree or len(self.products) == 0:
            return []
        n = len(self.products)
        res_pairs = self.seg_tree.range_query(0, n - 1, low, high, 0, n - 1, 0)
        # Map indices back to product dicts without enumerate
        out = []
        j = 0
        while j < len(res_pairs):
            (_, idx) = res_pairs[j]
            out.append(self.products[idx])
            j += 1
        return out


# ===================== Example usage =====================

ps = ProductSystem("DATA.csv")
ps100 = ProductSystem("products_100.csv")
ps500 = ProductSystem("products_500.csv")
ps1000 = ProductSystem("products_1000.csv")
ps300 = ProductSystem("products_300.csv")
ps800 = ProductSystem("products_800.csv")

print("\n🔹 Filter products between 500 and 6000:")
for prod in ps.filter_by_price(500, 6000):
    print(prod)

ps.update_price("P102", 1999)

ps.insert("P107", 3000, "Sports", "2025-07-12")

print("\n🔹 Filter products between 2000 and 4000:")
for prod in ps100.filter_by_price(2000, 4000):
    print(prod)
print("\n🔹 Filter products between 500 and 1500:")
for prod in ps500.filter_by_price(500, 1500):
    print(prod)
print("\n🔹 Filter products between 500 and 2500:")
for prod in ps1000.filter_by_price(500, 2500):
    print(prod)
print("\n🔹 Filter products between 999 and 1999:")    
for prod in ps300.filter_by_price(999, 1999):
    print(prod)
print("\n🔹 Filter products between 899 and 3999:")
for prod in ps800.filter_by_price(899, 3999):
    print(prod)
# Out:
# 🔹 Filter products between 500 and 6000:
# {'Product_ID': 'P102', 'Price': 1999, 'Category': 'Accessories', 'Date': '02-07-2025'}
# {'Product_ID': 'P106', 'Price': 2500, 'Category': 'Sports', 'Date': '06-07-2025'}
# {'Product_ID': 'P107', 'Price': 3000, 'Category': 'Sports', 'Date': '2025-07-12'}
# {'Product_ID': 'P103', 'Price': 4999, 'Category': 'Home Kitchen', 'Date': '03-07-2025'}
# Updated price of P102 from 1999 to 1999.
#
# 🔹 Filter products between 2000 and 4000:
# {'Product_ID': 'P0046', 'Price': 2414, 'Category': 'Beauty', 'Date': '04-07-2025'}
# {'Product_ID': 'P0042', 'Price': 2421, 'Category': 'Toys', 'Date': '31-07-2025'}
# {'Product_ID': 'P0040', 'Price': 2578, 'Category': 'Stationery', 'Date': '24-07-2025'}
# {'Product_ID': 'P0037', 'Price': 2720, 'Category': 'Fashion', 'Date': '11-07-2025'}
# {'Product_ID': 'P0079', 'Price': 3034, 'Category': 'Books', 'Date': '28-07-2025'}
# {'Product_ID': 'P0020', 'Price': 3243, 'Category': 'Sports', 'Date': '12-07-2025'}
# {'Product_ID': 'P0039', 'Price': 3525, 'Category': 'Toys', 'Date': '23-07-2025'}
# {'Product_ID': 'P0075', 'Price': 3775, 'Category': 'Home Kitchen', 'Date': '01-07-2025'}
# {'Product_ID': 'P0057', 'Price': 3803, 'Category': 'Accessories', 'Date': '28-07-2025'}
#
# 🔹 Filter products between 500 and 1500:
# {'Product_ID': 'P0357', 'Price': 538, 'Category': 'Fashion', 'Date': '22-07-2025'}
# {'Product_ID': 'P0325', 'Price': 550, 'Category': 'Fashion', 'Date': '21-07-2025'}
# {'Product_ID': 'P0097', 'Price': 619, 'Category': 'Laptop', 'Date': '25-07-2025'}
# {'Product_ID': 'P0213', 'Price': 652, 'Category': 'Toys', 'Date': '20-07-2025'}
# {'Product_ID': 'P0370', 'Price': 756, 'Category': 'Toys', 'Date': '30-07-2025'}
# {'Product_ID': 'P0270', 'Price': 780, 'Category': 'Fashion', 'Date': '16-07-2025'}
# {'Product_ID': 'P0419', 'Price': 810, 'Category': 'Accessories', 'Date': '08-07-2025'}
# {'Product_ID': 'P0173', 'Price': 824, 'Category': 'Home Kitchen', 'Date': '24-07-2025'}
# {'Product_ID': 'P0460', 'Price': 912, 'Category': 'Toys', 'Date': '19-07-2025'}
# {'Product_ID': 'P0002', 'Price': 933, 'Category': 'Laptop', 'Date': '13-07-2025'}
# {'Product_ID': 'P0266', 'Price': 973, 'Category': 'Home Kitchen', 'Date': '27-07-2025'}
# {'Product_ID': 'P0073', 'Price': 980, 'Category': 'Sports', 'Date': '16-07-2025'}
# {'Product_ID': 'P0190', 'Price': 1019, 'Category': 'Electronics', 'Date': '11-07-2025'}
# {'Product_ID': 'P0448', 'Price': 1021, 'Category': 'Stationery', 'Date': '28-07-2025'}
# {'Product_ID': 'P0488', 'Price': 1122, 'Category': 'Laptop', 'Date': '28-07-2025'}
# {'Product_ID': 'P0342', 'Price': 1124, 'Category': 'Stationery', 'Date': '08-07-2025'}
# {'Product_ID': 'P0204', 'Price': 1161, 'Category': 'Sports', 'Date': '03-07-2025'}
# {'Product_ID': 'P0202', 'Price': 1193, 'Category': 'Laptop', 'Date': '04-07-2025'}
# {'Product_ID': 'P0031', 'Price': 1230, 'Category': 'Laptop', 'Date': '05-07-2025'}
# {'Product_ID': 'P0320', 'Price': 1237, 'Category': 'Home Kitchen', 'Date': '10-07-2025'}
# {'Product_ID': 'P0115', 'Price': 1246, 'Category': 'Electronics', 'Date': '01-07-2025'}
# {'Product_ID': 'P0222', 'Price': 1481, 'Category': 'Toys', 'Date': '15-07-2025'}
#
# 🔹 Filter products between 500 and 2500:
# {'Product_ID': 'P0566', 'Price': 542, 'Category': 'Accessories', 'Date': '23-07-2025'}
# {'Product_ID': 'P0167', 'Price': 554, 'Category': 'Laptop', 'Date': '18-07-2025'}
# {'Product_ID': 'P0137', 'Price': 579, 'Category': 'Beauty', 'Date': '16-07-2025'}
# {'Product_ID': 'P0502', 'Price': 598, 'Category': 'Stationery', 'Date': '07-07-2025'}
# {'Product_ID': 'P0287', 'Price': 610, 'Category': 'Books', 'Date': '03-07-2025'}
# {'Product_ID': 'P0257', 'Price': 618, 'Category': 'Toys', 'Date': '14-07-2025'}
# {'Product_ID': 'P0141', 'Price': 637, 'Category': 'Laptop', 'Date': '13-07-2025'}
# {'Product_ID': 'P0666', 'Price': 650, 'Category': 'Beauty', 'Date': '23-07-2025'}
# {'Product_ID': 'P0690', 'Price': 661, 'Category': 'Toys', 'Date': '08-07-2025'}
# {'Product_ID': 'P0283', 'Price': 668, 'Category': 'Sports', 'Date': '04-07-2025'}
# {'Product_ID': 'P0240', 'Price': 681, 'Category': 'Home Kitchen', 'Date': '19-07-2025'}
# {'Product_ID': 'P0222', 'Price': 684, 'Category': 'Toys', 'Date': '29-07-2025'}
# {'Product_ID': 'P0997', 'Price': 693, 'Category': 'Books', 'Date': '29-07-2025'}
# {'Product_ID': 'P0121', 'Price': 699, 'Category': 'Books', 'Date': '01-07-2025'}
# {'Product_ID': 'P0609', 'Price': 718, 'Category': 'Stationery', 'Date': '18-07-2025'}
# {'Product_ID': 'P0436', 'Price': 733, 'Category': 'Beauty', 'Date': '19-07-2025'}
# {'Product_ID': 'P0039', 'Price': 735, 'Category': 'Laptop', 'Date': '04-07-2025'}
# {'Product_ID': 'P0645', 'Price': 749, 'Category': 'Toys', 'Date': '20-07-2025'}
# {'Product_ID': 'P0864', 'Price': 768, 'Category': 'Toys', 'Date': '03-07-2025'}
# {'Product_ID': 'P0370', 'Price': 783, 'Category': 'Laptop', 'Date': '19-07-2025'}
# {'Product_ID': 'P0277', 'Price': 805, 'Category': 'Home Kitchen', 'Date': '05-07-2025'}
# {'Product_ID': 'P0385', 'Price': 807, 'Category': 'Sports', 'Date': '04-07-2025'}
# {'Product_ID': 'P0294', 'Price': 849, 'Category': 'Accessories', 'Date': '12-07-2025'}
# {'Product_ID': 'P0852', 'Price': 849, 'Category': 'Toys', 'Date': '12-07-2025'}
# {'Product_ID': 'P0453', 'Price': 856, 'Category': 'Sports', 'Date': '11-07-2025'}
# {'Product_ID': 'P0616', 'Price': 891, 'Category': 'Electronics', 'Date': '28-07-2025'}
# {'Product_ID': 'P0305', 'Price': 911, 'Category': 'Stationery', 'Date': '07-07-2025'}
# {'Product_ID': 'P0344', 'Price': 920, 'Category': 'Accessories', 'Date': '25-07-2025'}
# {'Product_ID': 'P0165', 'Price': 957, 'Category': 'Stationery', 'Date': '08-07-2025'}
# {'Product_ID': 'P0834', 'Price': 964, 'Category': 'Stationery', 'Date': '12-07-2025'}
# {'Product_ID': 'P0116', 'Price': 997, 'Category': 'Accessories', 'Date': '02-07-2025'}
# {'Product_ID': 'P0186', 'Price': 1022, 'Category': 'Sports', 'Date': '21-07-2025'}
# {'Product_ID': 'P0624', 'Price': 1056, 'Category': 'Toys', 'Date': '05-07-2025'}
# {'Product_ID': 'P0958', 'Price': 1065, 'Category': 'Books', 'Date': '03-07-2025'}
# {'Product_ID': 'P0792', 'Price': 1081, 'Category': 'Fashion', 'Date': '18-07-2025'}
# {'Product_ID': 'P0461', 'Price': 1089, 'Category': 'Home Kitchen', 'Date': '30-07-2025'}
# {'Product_ID': 'P0359', 'Price': 1094, 'Category': 'Toys', 'Date': '25-07-2025'}
# {'Product_ID': 'P0454', 'Price': 1105, 'Category': 'Home Kitchen', 'Date': '02-07-2025'}
# {'Product_ID': 'P0400', 'Price': 1114, 'Category': 'Stationery', 'Date': '16-07-2025'}
# {'Product_ID': 'P0625', 'Price': 1122, 'Category': 'Sports', 'Date': '11-07-2025'}
# {'Product_ID': 'P0546', 'Price': 1154, 'Category': 'Books', 'Date': '09-07-2025'}
# {'Product_ID': 'P0207', 'Price': 1165, 'Category': 'Sports', 'Date': '15-07-2025'}
# {'Product_ID': 'P0972', 'Price': 1180, 'Category': 'Accessories', 'Date': '15-07-2025'}
# {'Product_ID': 'P0752', 'Price': 1211, 'Category': 'Sports', 'Date': '07-07-2025'}
# {'Product_ID': 'P0285', 'Price': 1265, 'Category': 'Electronics', 'Date': '15-07-2025'}
# {'Product_ID': 'P0153', 'Price': 1268, 'Category': 'Fashion', 'Date': '01-07-2025'}
# {'Product_ID': 'P0409', 'Price': 1310, 'Category': 'Electronics', 'Date': '26-07-2025'}
# {'Product_ID': 'P0384', 'Price': 1317, 'Category': 'Home Kitchen', 'Date': '20-07-2025'}
# {'Product_ID': 'P0310', 'Price': 1319, 'Category': 'Stationery', 'Date': '11-07-2025'}
# {'Product_ID': 'P0404', 'Price': 1345, 'Category': 'Toys', 'Date': '11-07-2025'}
# {'Product_ID': 'P0044', 'Price': 1349, 'Category': 'Electronics', 'Date': '28-07-2025'}
# {'Product_ID': 'P0741', 'Price': 1362, 'Category': 'Home Kitchen', 'Date': '24-07-2025'}
# {'Product_ID': 'P0817', 'Price': 1370, 'Category': 'Stationery', 'Date': '13-07-2025'}
# {'Product_ID': 'P0474', 'Price': 1371, 'Category': 'Books', 'Date': '30-07-2025'}
# {'Product_ID': 'P0658', 'Price': 1383, 'Category': 'Home Kitchen', 'Date': '28-07-2025'}
# {'Product_ID': 'P0780', 'Price': 1396, 'Category': 'Stationery', 'Date': '11-07-2025'}
# {'Product_ID': 'P0908', 'Price': 1424, 'Category': 'Books', 'Date': '28-07-2025'}
# {'Product_ID': 'P0065', 'Price': 1443, 'Category': 'Stationery', 'Date': '11-07-2025'}
# {'Product_ID': 'P0748', 'Price': 1464, 'Category': 'Books', 'Date': '12-07-2025'}
# {'Product_ID': 'P0093', 'Price': 1566, 'Category': 'Accessories', 'Date': '13-07-2025'}
# {'Product_ID': 'P0552', 'Price': 1580, 'Category': 'Sports', 'Date': '14-07-2025'}
# {'Product_ID': 'P0525', 'Price': 1598, 'Category': 'Fashion', 'Date': '17-07-2025'}
# {'Product_ID': 'P0796', 'Price': 1628, 'Category': 'Accessories', 'Date': '27-07-2025'}
# {'Product_ID': 'P0443', 'Price': 1651, 'Category': 'Laptop', 'Date': '16-07-2025'}
# {'Product_ID': 'P0879', 'Price': 1661, 'Category': 'Sports', 'Date': '07-07-2025'}
# {'Product_ID': 'P0444', 'Price': 1665, 'Category': 'Electronics', 'Date': '29-07-2025'}
# {'Product_ID': 'P0567', 'Price': 1749, 'Category': 'Sports', 'Date': '21-07-2025'}
# {'Product_ID': 'P0762', 'Price': 1791, 'Category': 'Toys', 'Date': '24-07-2025'}
# {'Product_ID': 'P0897', 'Price': 1807, 'Category': 'Home Kitchen', 'Date': '31-07-2025'}
# {'Product_ID': 'P0095', 'Price': 1818, 'Category': 'Stationery', 'Date': '18-07-2025'}
# {'Product_ID': 'P0892', 'Price': 1873, 'Category': 'Books', 'Date': '01-07-2025'}
# {'Product_ID': 'P0457', 'Price': 1874, 'Category': 'Toys', 'Date': '03-07-2025'}
# {'Product_ID': 'P0708', 'Price': 1878, 'Category': 'Electronics', 'Date': '25-07-2025'}
# {'Product_ID': 'P0403', 'Price': 1880, 'Category': 'Laptop', 'Date': '11-07-2025'}
# {'Product_ID': 'P0108', 'Price': 1934, 'Category': 'Books', 'Date': '13-07-2025'}
# {'Product_ID': 'P0636', 'Price': 1938, 'Category': 'Fashion', 'Date': '21-07-2025'}
# {'Product_ID': 'P0523', 'Price': 2019, 'Category': 'Toys', 'Date': '20-07-2025'}
# {'Product_ID': 'P0856', 'Price': 2036, 'Category': 'Home Kitchen', 'Date': '06-07-2025'}
# {'Product_ID': 'P0237', 'Price': 2074, 'Category': 'Books', 'Date': '19-07-2025'}
# {'Product_ID': 'P0723', 'Price': 2081, 'Category': 'Laptop', 'Date': '25-07-2025'}
# {'Product_ID': 'P0429', 'Price': 2100, 'Category': 'Stationery', 'Date': '13-07-2025'}
# {'Product_ID': 'P0681', 'Price': 2123, 'Category': 'Laptop', 'Date': '07-07-2025'}
# {'Product_ID': 'P0920', 'Price': 2125, 'Category': 'Accessories', 'Date': '01-07-2025'}
# {'Product_ID': 'P0757', 'Price': 2137, 'Category': 'Sports', 'Date': '22-07-2025'}
# {'Product_ID': 'P0863', 'Price': 2145, 'Category': 'Electronics', 'Date': '10-07-2025'}
# {'Product_ID': 'P0521', 'Price': 2192, 'Category': 'Accessories', 'Date': '05-07-2025'}
# {'Product_ID': 'P0298', 'Price': 2253, 'Category': 'Books', 'Date': '15-07-2025'}
# {'Product_ID': 'P0807', 'Price': 2268, 'Category': 'Stationery', 'Date': '21-07-2025'}
# {'Product_ID': 'P0320', 'Price': 2281, 'Category': 'Beauty', 'Date': '15-07-2025'}
# {'Product_ID': 'P0109', 'Price': 2284, 'Category': 'Sports', 'Date': '10-07-2025'}
# {'Product_ID': 'P0211', 'Price': 2294, 'Category': 'Electronics', 'Date': '07-07-2025'}
# {'Product_ID': 'P0020', 'Price': 2320, 'Category': 'Books', 'Date': '18-07-2025'}
# {'Product_ID': 'P0904', 'Price': 2328, 'Category': 'Laptop', 'Date': '06-07-2025'}
# {'Product_ID': 'P0706', 'Price': 2359, 'Category': 'Laptop', 'Date': '27-07-2025'}
# {'Product_ID': 'P0125', 'Price': 2428, 'Category': 'Sports', 'Date': '14-07-2025'}
# {'Product_ID': 'P0061', 'Price': 2468, 'Category': 'Beauty', 'Date': '02-07-2025'}
# {'Product_ID': 'P0743', 'Price': 2470, 'Category': 'Laptop', 'Date': '20-07-2025'}
#
# 🔹 Filter products between 999 and 1999:
# {'Product_ID': 'P0258', 'Price': 1043, 'Category': 'Home Kitchen', 'Date': '05-07-2025'}
# {'Product_ID': 'P0233', 'Price': 1074, 'Category': 'Fashion', 'Date': '18-07-2025'}
# {'Product_ID': 'P0212', 'Price': 1091, 'Category': 'Electronics', 'Date': '11-07-2025'}
# {'Product_ID': 'P0127', 'Price': 1163, 'Category': 'Sports', 'Date': '06-07-2025'}
# {'Product_ID': 'P0145', 'Price': 1174, 'Category': 'Sports', 'Date': '20-07-2025'}
# {'Product_ID': 'P0128', 'Price': 1186, 'Category': 'Electronics', 'Date': '08-07-2025'}
# {'Product_ID': 'P0198', 'Price': 1249, 'Category': 'Home Kitchen', 'Date': '01-07-2025'}
# {'Product_ID': 'P0154', 'Price': 1419, 'Category': 'Sports', 'Date': '05-07-2025'}
# {'Product_ID': 'P0004', 'Price': 1430, 'Category': 'Electronics', 'Date': '07-07-2025'}
# {'Product_ID': 'P0076', 'Price': 1477, 'Category': 'Laptop', 'Date': '26-07-2025'}
# {'Product_ID': 'P0265', 'Price': 1477, 'Category': 'Beauty', 'Date': '02-07-2025'}
# {'Product_ID': 'P0120', 'Price': 1482, 'Category': 'Fashion', 'Date': '23-07-2025'}
# {'Product_ID': 'P0014', 'Price': 1491, 'Category': 'Accessories', 'Date': '18-07-2025'}
# {'Product_ID': 'P0003', 'Price': 1568, 'Category': 'Sports', 'Date': '12-07-2025'}
# {'Product_ID': 'P0277', 'Price': 1600, 'Category': 'Electronics', 'Date': '22-07-2025'}
# {'Product_ID': 'P0275', 'Price': 1644, 'Category': 'Accessories', 'Date': '18-07-2025'}
# {'Product_ID': 'P0021', 'Price': 1656, 'Category': 'Toys', 'Date': '10-07-2025'}
# {'Product_ID': 'P0192', 'Price': 1662, 'Category': 'Beauty', 'Date': '06-07-2025'}
# {'Product_ID': 'P0166', 'Price': 1734, 'Category': 'Toys', 'Date': '05-07-2025'}
#
# 🔹 Filter products between 899 and 3999:
# {'Product_ID': 'P0742', 'Price': 934, 'Category': 'Beauty', 'Date': '08-07-2025'}
# {'Product_ID': 'P0191', 'Price': 961, 'Category': 'Electronics', 'Date': '23-07-2025'}
# {'Product_ID': 'P0519', 'Price': 970, 'Category': 'Beauty', 'Date': '12-07-2025'}
# {'Product_ID': 'P0036', 'Price': 974, 'Category': 'Fashion', 'Date': '26-07-2025'}
# {'Product_ID': 'P0257', 'Price': 987, 'Category': 'Books', 'Date': '07-07-2025'}
# {'Product_ID': 'P0030', 'Price': 988, 'Category': 'Beauty', 'Date': '17-07-2025'}
# {'Product_ID': 'P0143', 'Price': 995, 'Category': 'Home Kitchen', 'Date': '31-07-2025'}
# {'Product_ID': 'P0527', 'Price': 1017, 'Category': 'Home Kitchen', 'Date': '30-07-2025'}
# {'Product_ID': 'P0631', 'Price': 1045, 'Category': 'Home Kitchen', 'Date': '09-07-2025'}
# {'Product_ID': 'P0195', 'Price': 1064, 'Category': 'Accessories', 'Date': '26-07-2025'}
# {'Product_ID': 'P0665', 'Price': 1068, 'Category': 'Books', 'Date': '19-07-2025'}
# {'Product_ID': 'P0699', 'Price': 1076, 'Category': 'Stationery', 'Date': '01-07-2025'}
# {'Product_ID': 'P0405', 'Price': 1080, 'Category': 'Electronics', 'Date': '22-07-2025'}
# {'Product_ID': 'P0064', 'Price': 1126, 'Category': 'Laptop', 'Date': '07-07-2025'}
# {'Product_ID': 'P0238', 'Price': 1143, 'Category': 'Beauty', 'Date': '15-07-2025'}
# {'Product_ID': 'P0539', 'Price': 1177, 'Category': 'Toys', 'Date': '13-07-2025'}
# {'Product_ID': 'P0597', 'Price': 1212, 'Category': 'Books', 'Date': '15-07-2025'}
# {'Product_ID': 'P0763', 'Price': 1262, 'Category': 'Accessories', 'Date': '06-07-2025'}
# {'Product_ID': 'P0375', 'Price': 1281, 'Category': 'Fashion', 'Date': '31-07-2025'}
# {'Product_ID': 'P0287', 'Price': 1292, 'Category': 'Toys', 'Date': '13-07-2025'}
# {'Product_ID': 'P0421', 'Price': 1300, 'Category': 'Books', 'Date': '17-07-2025'}
# {'Product_ID': 'P0228', 'Price': 1310, 'Category': 'Fashion', 'Date': '28-07-2025'}
# {'Product_ID': 'P0489', 'Price': 1336, 'Category': 'Sports', 'Date': '12-07-2025'}
# {'Product_ID': 'P0413', 'Price': 1400, 'Category': 'Fashion', 'Date': '24-07-2025'}
# {'Product_ID': 'P0218', 'Price': 1406, 'Category': 'Books', 'Date': '18-07-2025'}
# {'Product_ID': 'P0660', 'Price': 1406, 'Category': 'Home Kitchen', 'Date': '12-07-2025'}
# {'Product_ID': 'P0379', 'Price': 1425, 'Category': 'Beauty', 'Date': '22-07-2025'}
# {'Product_ID': 'P0115', 'Price': 1433, 'Category': 'Books', 'Date': '28-07-2025'}
# {'Product_ID': 'P0500', 'Price': 1436, 'Category': 'Electronics', 'Date': '05-07-2025'}
# {'Product_ID': 'P0231', 'Price': 1460, 'Category': 'Fashion', 'Date': '04-07-2025'}
# {'Product_ID': 'P0104', 'Price': 1462, 'Category': 'Accessories', 'Date': '12-07-2025'}
# {'Product_ID': 'P0124', 'Price': 1497, 'Category': 'Electronics', 'Date': '26-07-2025'}
# {'Product_ID': 'P0707', 'Price': 1551, 'Category': 'Toys', 'Date': '31-07-2025'}
# {'Product_ID': 'P0083', 'Price': 1577, 'Category': 'Stationery', 'Date': '17-07-2025'}
# {'Product_ID': 'P0592', 'Price': 1592, 'Category': 'Toys', 'Date': '05-07-2025'}
# {'Product_ID': 'P0531', 'Price': 1596, 'Category': 'Sports', 'Date': '28-07-2025'}
# {'Product_ID': 'P0090', 'Price': 1599, 'Category': 'Laptop', 'Date': '27-07-2025'}
# {'Product_ID': 'P0428', 'Price': 1601, 'Category': 'Books', 'Date': '18-07-2025'}
# {'Product_ID': 'P0172', 'Price': 1619, 'Category': 'Accessories', 'Date': '09-07-2025'}
# {'Product_ID': 'P0658', 'Price': 1655, 'Category': 'Stationery', 'Date': '17-07-2025'}
# {'Product_ID': 'P0204', 'Price': 1712, 'Category': 'Sports', 'Date': '27-07-2025'}
# {'Product_ID': 'P0310', 'Price': 1776, 'Category': 'Electronics', 'Date': '20-07-2025'}
# {'Product_ID': 'P0178', 'Price': 1791, 'Category': 'Beauty', 'Date': '28-07-2025'}
# {'Product_ID': 'P0011', 'Price': 1806, 'Category': 'Beauty', 'Date': '27-07-2025'}
# {'Product_ID': 'P0279', 'Price': 1828, 'Category': 'Toys', 'Date': '26-07-2025'}
# {'Product_ID': 'P0336', 'Price': 1833, 'Category': 'Stationery', 'Date': '22-07-2025'}
# {'Product_ID': 'P0139', 'Price': 1878, 'Category': 'Home Kitchen', 'Date': '30-07-2025'}
# {'Product_ID': 'P0289', 'Price': 1972, 'Category': 'Home Kitchen', 'Date': '26-07-2025'}
# {'Product_ID': 'P0554', 'Price': 1975, 'Category': 'Accessories', 'Date': '21-07-2025'}
# {'Product_ID': 'P0239', 'Price': 1993, 'Category': 'Home Kitchen', 'Date': '15-07-2025'}
# {'Product_ID': 'P0266', 'Price': 1996, 'Category': 'Toys', 'Date': '21-07-2025'}
# {'Product_ID': 'P0689', 'Price': 2036, 'Category': 'Home Kitchen', 'Date': '03-07-2025'}
# {'Product_ID': 'P0778', 'Price': 2079, 'Category': 'Sports', 'Date': '30-07-2025'}
# {'Product_ID': 'P0013', 'Price': 2120, 'Category': 'Beauty', 'Date': '30-07-2025'}
# {'Product_ID': 'P0740', 'Price': 2135, 'Category': 'Laptop', 'Date': '08-07-2025'}
# {'Product_ID': 'P0316', 'Price': 2152, 'Category': 'Beauty', 'Date': '23-07-2025'}
# {'Product_ID': 'P0460', 'Price': 2158, 'Category': 'Accessories', 'Date': '14-07-2025'}
# {'Product_ID': 'P0396', 'Price': 2202, 'Category': 'Accessories', 'Date': '28-07-2025'}
# {'Product_ID': 'P0594', 'Price': 2202, 'Category': 'Sports', 'Date': '11-07-2025'}
# {'Product_ID': 'P0723', 'Price': 2218, 'Category': 'Electronics', 'Date': '21-07-2025'}
# {'Product_ID': 'P0720', 'Price': 2240, 'Category': 'Beauty', 'Date': '23-07-2025'}
# {'Product_ID': 'P0561', 'Price': 2241, 'Category': 'Beauty', 'Date': '23-07-2025'}
# {'Product_ID': 'P0026', 'Price': 2258, 'Category': 'Laptop', 'Date': '21-07-2025'}
# {'Product_ID': 'P0098', 'Price': 2259, 'Category': 'Fashion', 'Date': '12-07-2025'}
# {'Product_ID': 'P0056', 'Price': 2266, 'Category': 'Home Kitchen', 'Date': '28-07-2025'}
# {'Product_ID': 'P0435', 'Price': 2273, 'Category': 'Electronics', 'Date': '11-07-2025'}
# {'Product_ID': 'P0209', 'Price': 2277, 'Category': 'Electronics', 'Date': '26-07-2025'}
# {'Product_ID': 'P0540', 'Price': 2345, 'Category': 'Stationery', 'Date': '18-07-2025'}
# {'Product_ID': 'P0312', 'Price': 2407, 'Category': 'Stationery', 'Date': '05-07-2025'}
# {'Product_ID': 'P0084', 'Price': 2423, 'Category': 'Home Kitchen', 'Date': '07-07-2025'}
# {'Product_ID': 'P0426', 'Price': 2449, 'Category': 'Fashion', 'Date': '04-07-2025'}
# {'Product_ID': 'P0272', 'Price': 2482, 'Category': 'Sports', 'Date': '07-07-2025'}
# {'Product_ID': 'P0388', 'Price': 2496, 'Category': 'Fashion', 'Date': '08-07-2025'}
# {'Product_ID': 'P0692', 'Price': 2496, 'Category': 'Electronics', 'Date': '20-07-2025'}
# {'Product_ID': 'P0772', 'Price': 2514, 'Category': 'Beauty', 'Date': '28-07-2025'}
# {'Product_ID': 'P0514', 'Price': 2524, 'Category': 'Beauty', 'Date': '19-07-2025'}
# {'Product_ID': 'P0028', 'Price': 2526, 'Category': 'Home Kitchen', 'Date': '08-07-2025'}
# {'Product_ID': 'P0600', 'Price': 2552, 'Category': 'Fashion', 'Date': '12-07-2025'}
# {'Product_ID': 'P0474', 'Price': 2619, 'Category': 'Books', 'Date': '25-07-2025'}
# {'Product_ID': 'P0031', 'Price': 2658, 'Category': 'Laptop', 'Date': '16-07-2025'}
# {'Product_ID': 'P0311', 'Price': 2659, 'Category': 'Sports', 'Date': '31-07-2025'}
# {'Product_ID': 'P0303', 'Price': 2695, 'Category': 'Stationery', 'Date': '31-07-2025'}
# {'Product_ID': 'P0330', 'Price': 2792, 'Category': 'Beauty', 'Date': '29-07-2025'}
# {'Product_ID': 'P0284', 'Price': 2852, 'Category': 'Books', 'Date': '15-07-2025'}
# {'Product_ID': 'P0043', 'Price': 2891, 'Category': 'Fashion', 'Date': '21-07-2025'}
# {'Product_ID': 'P0294', 'Price': 2914, 'Category': 'Stationery', 'Date': '31-07-2025'}
# {'Product_ID': 'P0545', 'Price': 2926, 'Category': 'Beauty', 'Date': '31-07-2025'}
# {'Product_ID': 'P0348', 'Price': 3063, 'Category': 'Books', 'Date': '31-07-2025'}
# {'Product_ID': 'P0501', 'Price': 3158, 'Category': 'Electronics', 'Date': '12-07-2025'}
# {'Product_ID': 'P0146', 'Price': 3186, 'Category': 'Home Kitchen', 'Date': '09-07-2025'}
# {'Product_ID': 'P0255', 'Price': 3219, 'Category': 'Accessories', 'Date': '07-07-2025'}
# {'Product_ID': 'P0779', 'Price': 3230, 'Category': 'Sports', 'Date': '13-07-2025'}
# {'Product_ID': 'P0446', 'Price': 3343, 'Category': 'Books', 'Date': '04-07-2025'}
# {'Product_ID': 'P0478', 'Price': 3371, 'Category': 'Home Kitchen', 'Date': '05-07-2025'}
# {'Product_ID': 'P0176', 'Price': 3378, 'Category': 'Beauty', 'Date': '07-07-2025'}
# {'Product_ID': 'P0705', 'Price': 3382, 'Category': 'Accessories', 'Date': '11-07-2025'}
# {'Product_ID': 'P0627', 'Price': 3386, 'Category': 'Accessories', 'Date': '07-07-2025'}
# {'Product_ID': 'P0785', 'Price': 3414, 'Category': 'Home Kitchen', 'Date': '14-07-2025'}
# {'Product_ID': 'P0027', 'Price': 3433, 'Category': 'Accessories', 'Date': '22-07-2025'}
# {'Product_ID': 'P0154', 'Price': 3453, 'Category': 'Fashion', 'Date': '21-07-2025'}
# {'Product_ID': 'P0700', 'Price': 3474, 'Category': 'Fashion', 'Date': '21-07-2025'}
# {'Product_ID': 'P0521', 'Price': 3496, 'Category': 'Toys', 'Date': '30-07-2025'}
# {'Product_ID': 'P0062', 'Price': 3507, 'Category': 'Toys', 'Date': '02-07-2025'}
# {'Product_ID': 'P0729', 'Price': 3522, 'Category': 'Beauty', 'Date': '30-07-2025'}
# {'Product_ID': 'P0041', 'Price': 3528, 'Category': 'Home Kitchen', 'Date': '06-07-2025'}
# {'Product_ID': 'P0321', 'Price': 3530, 'Category': 'Stationery', 'Date': '14-07-2025'}
# {'Product_ID': 'P0071', 'Price': 3562, 'Category': 'Toys', 'Date': '29-07-2025'}
# {'Product_ID': 'P0711', 'Price': 3570, 'Category': 'Accessories', 'Date': '10-07-2025'}
# {'Product_ID': 'P0569', 'Price': 3649, 'Category': 'Laptop', 'Date': '09-07-2025'}
# {'Product_ID': 'P0059', 'Price': 3661, 'Category': 'Accessories', 'Date': '26-07-2025'}
# {'Product_ID': 'P0475', 'Price': 3696, 'Category': 'Books', 'Date': '14-07-2025'}
# {'Product_ID': 'P0175', 'Price': 3714, 'Category': 'Books', 'Date': '21-07-2025'}
# {'Product_ID': 'P0765', 'Price': 3729, 'Category': 'Laptop', 'Date': '31-07-2025'}
# {'Product_ID': 'P0022', 'Price': 3755, 'Category': 'Fashion', 'Date': '19-07-2025'}
# {'Product_ID': 'P0794', 'Price': 3778, 'Category': 'Fashion', 'Date': '25-07-2025'}
# {'Product_ID': 'P0023', 'Price': 3891, 'Category': 'Stationery', 'Date': '19-07-2025'}
# {'Product_ID': 'P0371', 'Price': 3899, 'Category': 'Home Kitchen', 'Date': '31-07-2025'}
# {'Product_ID': 'P0423', 'Price': 3929, 'Category': 'Beauty', 'Date': '20-07-2025'}
# {'Product_ID': 'P0451', 'Price': 3949, 'Category': 'Laptop', 'Date': '18-07-2025'}
# {'Product_ID': 'P0073', 'Price': 3959, 'Category': 'Laptop', 'Date': '04-07-2025'}
# {'Product_ID': 'P0712', 'Price': 3975, 'Category': 'Fashion', 'Date': '20-07-2025'}
# {'Product_ID': 'P0588', 'Price': 3979, 'Category': 'Stationery', 'Date': '27-07-2025'}
# {'Product_ID': 'P0173', 'Price': 3985, 'Category': 'Laptop', 'Date': '17-07-2025'}
# {'Product_ID': 'P0362', 'Price': 3999, 'Category': 'Fashion', 'Date': '04-07-2025'}
